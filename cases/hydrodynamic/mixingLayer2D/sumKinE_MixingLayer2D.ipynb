# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from matplotlib import rcParams
rcParams["figure.dpi"] = 400
import random 

df_interIso = pd.read_csv('interIsoFoam-mixingLayer2D_00000_templateCase/SumKinE.dat', header = 0, sep='\t')
df_interIso1 = pd.read_csv('interIsoFoam-mixingLayer2D_00001_templateCase/SumKinE.dat', header = 0, sep='\t')
df_interIso2 = pd.read_csv('interIsoFoam-mixingLayer2D_00002_templateCase/SumKinE.dat', header = 0, sep='\t')
df_interIsoRho = pd.read_csv('interIsoRhoFoam-mixingLayer2D_00000_templateCase/SumKinE.dat', header = 0, sep='\t')
#plt.plot(df_interIso['time'],df_interIso['SumKinE']/df_interIso.at[0,'SumKinE'],ms=3,label='interIsoFoam')
#plt.plot(df_interIso1['time'],df_interIso1['SumKinE']/df_interIso1.at[0,'SumKinE'],ms=3,label='interIsoFoam1')
plt.plot(df_interIso['time'],df_interIso['SumKinE1']/df_interIso.at[0,'SumKinE1'],ms=3,label='interIsoFoam')
plt.plot(df_interIsoRho['time'],df_interIsoRho['SumKinE1']/df_interIsoRho.at[0,'SumKinE1'],ms=3,label='interIsoRhoFoam')
###------------------------------------------###
df_interIso_N256 = pd.read_csv('N256-interIsoFoam-mixingLayer2D_00000_templateCase/SumKinE.dat', header = 0, sep='\t')
df_interIsoRho_N256  = pd.read_csv('N256-interIsoRhoFoam-mixingLayer2D_00000_templateCase/SumKinE.dat', header = 0, sep='\t')
#plt.plot(df_interIso['time'],df_interIso['SumKinE']/df_interIso.at[0,'SumKinE'],ms=3,label='interIsoFoam')
#plt.plot(df_interIso1['time'],df_interIso1['SumKinE']/df_interIso1.at[0,'SumKinE'],ms=3,label='interIsoFoam1')
plt.plot(df_interIso_N256 ['time'],df_interIso_N256 ['SumKinE']/df_interIso_N256 .at[0,'SumKinE'],ms=3,label='interIsoFoam_N256 ')
plt.plot(df_interIsoRho_N256 ['time'],df_interIsoRho_N256 ['SumKinE']/df_interIsoRho_N256 .at[0,'SumKinE'],ms=3,label='interIsoRhoFoam_N256 ')

plt.ylabel("Normalized kinetic energy")
plt.xlabel("Time in seconds")
plt.yscale('log')
   # plt.ylim(0.99,1.01)
plt.legend()

# %%
df_interIso = pd.read_csv('interIsoFoam-mixingLayer2D_00000_templateCase/SumKinE.dat', header = 0, sep='\t')
plt.plot(df_interIso['time'],df_interIso['SumKinE1']/df_interIso.at[0,'SumKinE1'],ms=3,label=r'$\sum 0.5m\mathbf{v}^2$')
plt.plot(df_interIso['time'],df_interIso['SumKinE2']/df_interIso.at[0,'SumKinE2'],ms=3,label=r'$\sum 0.5(m\mathbf{v})^2$')
plt.plot(df_interIso['time'],df_interIso['SumKinE3']/df_interIso.at[0,'SumKinE3'],ms=3,label=r'$|\sum m\mathbf{v}|$')
plt.plot(df_interIso['time'],df_interIso['SumKinE4']/df_interIso.at[0,'SumKinE4'],ms=3,label=r'$\sum |m\mathbf{v}|$')
plt.ylabel("Normalized kinetic energy")
plt.xlabel("Time in seconds")
plt.yscale('log')
   # plt.ylim(0.99,1.01)
plt.legend()

# %%
df_interIso = pd.read_csv('interIsoFoam-mixingLayer2D_00000_templateCase/SumKinE.dat', header = 0, sep='\t')
plt.plot(df_interIso['time'],df_interIso['SumKinE1']/df_interIso.at[0,'SumKinE1'],ms=3,label=r'$\sum 0.5\rho\mathbf{v}^2$')
plt.plot(df_interIso['time'],df_interIso['SumKinE2']/df_interIso.at[0,'SumKinE2'],ms=3,label=r'$\sum 0.5(\rho\mathbf{v})^2$')
plt.plot(df_interIso['time'],df_interIso['SumKinE3']/df_interIso.at[0,'SumKinE3'],ms=3,label=r'$|\sum \rho\mathbf{v}|$')
plt.plot(df_interIso['time'],df_interIso['SumKinE4']/df_interIso.at[0,'SumKinE4'],ms=3,label=r'$\sum |\rho\mathbf{v}|$')
plt.ylabel("Normalized kinetic energy")
plt.xlabel("Time in seconds")
plt.yscale('log')
   # plt.ylim(0.99,1.01)
plt.legend()

# %%
df_interIso = pd.read_csv('interIsoRhoFoam-mixingLayer2D_00000_templateCase/SumKinE.dat', header = 0, sep='\t')
plt.plot(df_interIso['time'],df_interIso['SumKinE1']/df_interIso.at[0,'SumKinE1'],ms=3,label=r'$\sum 0.5m\mathbf{v}^2$')
plt.plot(df_interIso['time'],df_interIso['SumKinE2']/df_interIso.at[0,'SumKinE2'],ms=3,label=r'$\sum 0.5\mathbf{mv}^2$')
plt.plot(df_interIso['time'],df_interIso['SumKinE3']/df_interIso.at[0,'SumKinE3'],ms=3,label=r'$|\sum m\mathbf{v}|$')
plt.plot(df_interIso['time'],df_interIso['SumKinE4']/df_interIso.at[0,'SumKinE4'],ms=3,label=r'$\sum |m\mathbf{v}|$')
plt.ylabel("Normalized kinetic energy")
plt.xlabel("Time in seconds")
plt.yscale('log')
   # plt.ylim(0.99,1.01)
plt.legend()

# %%
df_interIso_N256 = pd.read_csv('N256-interIsoFoam-mixingLayer2D_00000_templateCase/SumKinE.dat', header = 0, sep='\t')
df_interIsoRho_N256  = pd.read_csv('N256-interIsoRhoFoam-mixingLayer2D_00000_templateCase/SumKinE.dat', header = 0, sep='\t')
#plt.plot(df_interIso['time'],df_interIso['SumKinE']/df_interIso.at[0,'SumKinE'],ms=3,label='interIsoFoam')
#plt.plot(df_interIso1['time'],df_interIso1['SumKinE']/df_interIso1.at[0,'SumKinE'],ms=3,label='interIsoFoam1')
plt.plot(df_interIso_N256 ['time'],df_interIso_N256 ['SumKinE']/df_interIso_N256 .at[0,'SumKinE'],ms=3,label='interIsoFoam_N256 ')
plt.plot(df_interIsoRho_N256 ['time'],df_interIsoRho_N256 ['SumKinE']/df_interIsoRho_N256 .at[0,'SumKinE'],ms=3,label='interIsoRhoFoam_N256 ')

plt.ylabel("Normalized kinetic energy")
plt.xlabel("Time in seconds")
plt.yscale('log')
   # plt.ylim(0.99,1.01)
plt.legend()

# %% [markdown]
# # Euler+lV1

# %%
zFronts('damBreak_withRhoEqn/zFront.dat', 'interIsoRhoFoam,  1024x512, tSchemeEuler+Euler+GU, rhoRatio_1e4')
zFronts('damBreak/zFront.dat', 'interIsoFoam,  1024x512, Euler+GU, rhoRatio_1e4')

plt.plot(dB_Exp['dimensionless-time'],dB_Exp['z-front-pos'],marker='x',linestyle = 'None', ms=3, label='Experiment')

plt.ylabel(r"$z/a$")
plt.xlabel("Dimensionless time")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15))#,frameon=False)
plt.xlim(0,4)
plt.ylim(1,6.3)
plt.show()

# %%
maxInterfaceCo('damBreak_withRhoEqn/zFront.dat','interIsoRhoFoam,  1024x512, tSchemeEuler+Euler+GU, rhoRatio_1e4')
maxInterfaceCo('damBreak/zFront.dat','interIsoFoam,  1024x512, Euler+GU, rhoRatio_1e4')

plt.ylabel("Interface Co max")
plt.xlabel("Dimensionless time")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15))#,frameon=False)
plt.xlim(0,4)
#plt.ylim(1,6.3)
plt.show()

# %%
# dB_interIsoN64 = pd.read_csv('damBreak/Euler_lLV1/zFront_N64_Euler_lV1.dat', header = 0, sep='\t')
# dB_interIsoN64_newConf = pd.read_csv('damBreak/Euler_lLV1/zFront_N64_Euler_lV1_newConf.dat', header = 0, sep='\t')
dB_interIsoN128_newConf = pd.read_csv('damBreak/Euler_lLV1/zFront_N128_Euler_lV1_newConf.dat', header = 0, sep='\t')
# dB_interIsoRhoN64 = pd.read_csv('damBreak_withRhoEqn/Euler_lLv1/zFront_N64_Euler_lV1.dat', header = 0, sep='\t')
# dB_interIsoRhoN64_newConf = pd.read_csv('damBreak_withRhoEqn/Euler_lLv1/zFront_N64_Euler_lV1_newConf.dat', header = 0, sep='\t')
dB_interIsoRhoN128_newConf = pd.read_csv('damBreak_withRhoEqn/Euler_lLv1/zFront_N128_Euler_lV1_newConf.dat', header = 0, sep='\t')
dB_interIsoN128_newConf_CN_GU = pd.read_csv('damBreak/zFront_N128_CN_GU_newConf.dat', header = 0, sep='\t')
dB_interIsoRhoN128_newConf_CN_GU = pd.read_csv('damBreak_withRhoEqn/zFront_N128_CN_GU_newConf.dat', header = 0, sep='\t')
# dB_interIsoRhoN256_newConf_CN_CN_GU = pd.read_csv('damBreak_withRhoEqn/zFront_N256_CN_CN_GU_newConf.dat', header = 0, sep='\t')
# dB_interIsoRhoN256_newConf_Euler_Euler_GU = pd.read_csv('damBreak_withRhoEqn/zFront.dat', header = 0, sep='\t')
#dB_interIsoN128_newConf_CN_lLV1 = pd.read_csv('damBreak/zFront_N128_CN_lLV1_newConf.dat', header = 0, sep='\t')
# dB_interIsoN256_newConf_CN_GU = pd.read_csv('damBreak/zFront_N256_CN_GU_newConf.dat', header = 0, sep='\t')
#dB_interIsoRhoN128_newConf_CN_lLV1 = pd.read_csv('damBreak_withRhoEqn/zFront_N128_CN_lLV1_newConf.dat', header = 0, sep='\t')
dB_interIsoRhoN128_newConf_CN09_lLV1 = pd.read_csv('damBreak_withRhoEqn/zFront_N128_CN09_lLV1_newConf.dat', header = 0, sep='\t')
dB_interIsoRhoN128_newConf_CN09_GU = pd.read_csv('damBreak_withRhoEqn/zFront_N128_CN09_GU_newConf.dat', header = 0, sep='\t')

#dB_interIsoRhoN256_newConf_Euler_Euler_GU_1e4 = pd.read_csv('damBreak_withRhoEqn/zFront.dat', header = 0, sep='\t')
#dB_interIsoN256_newConf_Euler_GU_1e4 = pd.read_csv('damBreak/zFront.dat', header = 0, sep='\t')

L_scale=1/0.05715
t_scale=np.sqrt(9.81*L_scale)
plt.plot(dB_Exp['dimensionless-time'],dB_Exp['z-front-pos'],marker='x',linestyle = 'None', ms=3, label='Experiment')
# #plt.plot(dB_interIsoN64['time']*t_scale,dB_interIsoN64['z-front-pos']*L_scale,'-.',label='interIsoFoam, 256x64, tSchemeEuler+Euler+lLV1')
# #plt.plot(dB_interIsoN64_newConf['time']*t_scale,dB_interIsoN64_newConf['z-front-pos']*L_scale,'o',ms=3,label='interIsoFoam,  256x64, tSchemeEuler+Euler+lLV1, newConf')
plt.plot(dB_interIsoN128_newConf['time']*t_scale,dB_interIsoN128_newConf['z-front-pos']*L_scale,'1',ms=3,label='interIsoFoam,  512x128, Euler+lLV1, newConf')
# plt.plot(dB_interIsoN256_newConf_CN_GU['time']*t_scale,dB_interIsoN256_newConf_CN_GU['z-front-pos']*L_scale,'2',ms=3,label='interIsoFoam, 1024x512, CN+GU, newConf')
plt.plot(dB_interIsoN128_newConf_CN_GU['time']*t_scale,dB_interIsoN128_newConf_CN_GU['z-front-pos']*L_scale,'2',ms=3,label='interIsoFoam,  512x128, CN+GU, newConf')
plt.plot(dB_interIsoN128_newConf_CN_lLV1['time']*t_scale,dB_interIsoN128_newConf_CN_lLV1['z-front-pos']*L_scale,'4',ms=3,label='interIsoFoam,  512x128, CN+lLV1, newConf')
# #plt.plot(dB_interIsoRhoN64['time']*t_scale,dB_interIsoRhoN64['z-front-pos']*L_scale,':',label='interIsoRhoFoam, 256x64, tSchemeEuler+Euler+lLV1')
# plt.plot(dB_interIsoRhoN64_newConf['time']*t_scale,dB_interIsoRhoN64_newConf['z-front-pos']*L_scale,'*',ms=3,label='interIsoRhoFoam, 256x64, tSchemeEuler+Euler+lLV1, newConf')
plt.plot(dB_interIsoRhoN128_newConf['time']*t_scale,dB_interIsoRhoN128_newConf['z-front-pos']*L_scale,'--',ms=3,label='interIsoRhoFoam,  512x128, Euler+lLV1, newConf')
#plt.plot(dB_interIsoRhoN128_newConf_CN_GU['time']*t_scale,dB_interIsoRhoN128_newConf_CN_GU['z-front-pos']*L_scale,'3',ms=3,label='interIsoRhoFoam,  512x128, tSchemeCN+CN+GU, newConf')
#plt.plot(dB_interIsoRhoN128_newConf_CN_lLV1['time']*t_scale,dB_interIsoRhoN128_newConf_CN_lLV1['z-front-pos']*L_scale,ms=3,label='interIsoRhoFoam,  512x128, tSchemeCN+CN+lLV1, newConf')
plt.plot(dB_interIsoRhoN128_newConf_CN09_lLV1['time']*t_scale,dB_interIsoRhoN128_newConf_CN09_lLV1['z-front-pos']*L_scale,ms=3,label='interIsoRhoFoam,  512x128, CN+lLV1, newConf')
plt.plot(dB_interIsoRhoN128_newConf_CN09_GU['time']*t_scale,dB_interIsoRhoN128_newConf_CN09_GU['z-front-pos']*L_scale,ms=3,label='interIsoRhoFoam,  512x128, CN+GU, newConf')
# plt.plot(dB_interIsoRhoN256_newConf_CN_CN_GU['time']*t_scale,dB_interIsoRhoN256_newConf_CN_CN_GU['z-front-pos']*L_scale,'2',ms=3,label='interIsoRhoFoam,  1024x512, tSchemeCN+CN+GU, newConf')
# plt.plot(dB_interIsoRhoN256_newConf_Euler_Euler_GU['time']*t_scale,dB_interIsoRhoN256_newConf_Euler_Euler_GU['z-front-pos']*L_scale,'2',ms=3,label='interIsoRhoFoam,  1024x512, Euler+GU, newConf')

# zFronts('damBreak_withRhoEqn/zFront.dat', 'interIsoRhoFoam,  1024x512, tSchemeEuler+Euler+GU, rhoRatio_1e4')
# zFronts('../damBreak2D1e4/damBreak/zFront_ratio1e4_N256_Euler_GU_newConf.dat', 'interIsoFoam,  1024x512, Euler+GU, rhoRatio_1e4')
#zFronts('damBreak_newPhysicalProperties/zFront.dat', 'interIsoFoam,  1024x512, Euler+GU, newPhysicalProperties')

#plt.plot(dB_interIsoRhoN256_newConf_Euler_Euler_GU_1e4['time']*t_scale,dB_interIsoRhoN256_newConf_Euler_Euler_GU_1e4['z-front-pos']*L_scale,'2',ms=3,label='interIsoRhoFoam,  1024x512, tSchemeEuler+Euler+GU, newConf')
#plt.plot(dB_interIsoN256_newConf_Euler_GU_1e4['time']*t_scale,dB_interIsoN256_newConf_Euler_GU_1e4['z-front-pos']*L_scale,'2',ms=3,label='interIsoFoam,  1024x512,Euler+GU, newConf')
plt.ylabel(r"$z/a$")
plt.xlabel("Dimensionless time")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))#loc='upper center', bbox_to_anchor=(0.5, -0.15))#,frameon=False)
plt.xlim(0,4)
plt.ylim(1,6.3)
plt.show()

# %%
#plt.plot(dB_interIsoRhoN256_newConf_CN_CN_GU['time']*t_scale,dB_interIsoRhoN256_newConf_CN_CN_GU['interfaceCoMax'],label='interIsoRhoFoam,  1024x512, tSchemeCN+CN+GU, newConf')
#plt.plot(dB_interIsoRhoN256_newConf_Euler_Euler_GU['time']*t_scale,dB_interIsoRhoN256_newConf_Euler_Euler_GU['interfaceCoMax'],label='interIsoRhoFoam,  1024x512, tSchemeEuler+Euler+GU, newConf')

plt.plot(dB_interIsoRhoN256_newConf_Euler_Euler_GU_1e4['time']*t_scale,dB_interIsoRhoN256_newConf_Euler_Euler_GU_1e4['interfaceCoMax'],'2',ms=3,label='interIsoRhoFoam,  1024x512, tSchemeEuler+Euler+GU, newConf')
#plt.plot(dB_interIsoN256_newConf_Euler_GU_1e4['time']*t_scale,dB_interIsoN256_newConf_Euler_GU_1e4['z-front-pos']*L_scale,'2',ms=3,label='interIsoFoam,  1024x512,Euler+GU, newConf')

plt.ylabel("Interface Co max")
plt.xlabel("Dimensionless time")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15))#,frameon=False)
plt.xlim(0,4)
#plt.ylim(1,6.3)
plt.show()

# %% [markdown]
# # Euler + GU
